# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('../Dataset/flats_cleaned.csv')
house = pd.read_csv('../Dataset/house_cleaned.csv')

# %%
data = pd.concat([flats,house], ignore_index=True)

# %%
data = data.sample(data.shape[0], ignore_index=True)

# %%
data.head()
# Out:
#                       property_name property_type  \
# 0   3 BHK Flat in Sector 76 Gurgaon          flat
# 1   3 BHK Flat in Sector 54 Gurgaon          flat
# 2  3 BHK Flat in Sector 37D Gurgaon          flat
# 3   2 BHK Flat in Sector 95 Gurgaon          flat
# 4   2 BHK Flat in Sector 91 Gurgaon          flat
#
#                           society  price  price_per_sqft    area  \
# 0            whiteland blissville   1.92         11794.0  1628.0
# 1                  dlf park place   4.85         30180.0  1607.0
# 2  signature global city 37d ph 2   1.35          9375.0  1440.0
# 3               sidhartha ncr one   0.55          5556.0   990.0
# 4                      tarc maceo   0.96          5413.0  1774.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                 Built Up area: 1628 (151.25 sq.m.)        3         3
# 1  Super Built up area 1983(184.23 sq.m.)Built Up...        3         4
# ...

# %%
data.to_csv('../Dataset/gurgaon_properties.csv',index=False)
